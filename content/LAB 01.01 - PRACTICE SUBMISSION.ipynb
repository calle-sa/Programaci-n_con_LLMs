# %% [markdown]
# <a href="https://colab.research.google.com/github/calle-sa/Programaci-n_con_LLMs/blob/main/content/LAB%2001.01%20-%20PRACTICE%20SUBMISSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 01.01 - Practice submission
#
# <a target="_blank" href="https://colab.research.google.com/github/rramosp/ai4eng.v1/blob/main/content/LAB%2001.01%20-%20PRACTICE%20SUBMISSION.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/ai4eng.v1/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
import inspect
from local.lib.rlxmoocapi import session
session.LoginSequence(endpoint=init.endpoint, course_id=init.course_id, lab_id="L01.01", varname="student");
# Out:
# logging in as santiago.callea@udea.edu.co... please wait
#
# -------------
# using course session ai4eng.v1.udea.r4::2026.1
# success!! you are logged in
# -------------

# %% [markdown]
# ### Ejercicio 1: Suma dos matrices

# %% [markdown]
# Completa la función `suma_matrices` para que, dadas dos arrays numpy cualquiera devuelva la suma elemento a elemento.
#
# #### Ejemplo de ejecución
#
#     > s = np.array([1,2,3])
#     > t = np.array([4,5,6])
#     > suma_matrices(s,t)
#
#       [5 7 9]
#
# _Sugerencia_: completa el código de la siguiente manera:
#
#     def suma_matrices(a,b):
#        ## --- TU CODIGO AQUI ---
#        result = a + b
#        return result

# %%
def suma_matrices(a,b):
    result = a + b
    return result

# %% [markdown]
# comprueba manualmente tu código

# %%
import numpy as np
a = np.random.randint(10, size=(3,2))
b = np.random.randint(10, size=(3,2))
print (a)
print (b)
print (suma_matrices(a,b))
# Out:
# [[4 2]
#  [5 2]
#  [6 8]]
# [[4 4]
#  [2 6]
#  [5 0]]
# [[ 8  6]
#  [ 7  8]
#  [11  8]]

# %% [markdown]
# #### registra tu solución en línea

# %%
student.submit_task(globals(), task_id="task_01");
# Out:
#                     <b>task_01 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre><pre>
# checking your code with 100 random calls
# </pre><b>CORRECT</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> YKZA9mMkQ5ir1/W14Levi6h5+z1blftFs4QucjS2rlf4TThTlyyVpGKWyeTlvEpenHyvoqoLLVJ3mb/1h4JG9nYvfrLsUiijmpdZkHwF8Z8XkUideG8NgGC7uMvGYPIBKdo17b1t7612l+gH26eQ6+QOZTS6Ov/paLOBj2lcwTE=</div>

# %% [markdown]
# ### Ejercicio 2: Realiza un cálculo

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# En este ejercicio, al ejecutar la celda de más abajo, se generará una lista de número aleatorios.
#
# Tendrás que calcular el valor promedio de la lista y asignarlo a la variable `avg` más abajo.
#
# Puedes usar el método que quieras para realizar el cálculo (a mano, excel, python, etc.) lo que importa es el valor que obtengas.

# %%
import numpy as np
rlist = np.random.randint(100, size=10)
rlist
# Out:
# array([ 7, 55,  3, 31, 67, 86, 30, 68, 48,  0])

# %% [markdown]
# #### tu solución

# %%
avg = np.mean(rlist)
avg
# Out:
# np.float64(39.5)

# %% [markdown]
# #### registra tu solución en línea

# %%
student.submit_task(globals(), task_id="task_02");
# Out:
#                     <b>task_02 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> VWRA49avgalpC3Qu6cFSRy0q6PrQV63MOIJNkj2OJKJp5Nlsdbvbv8IeED0A8M/bF8jA5EDK+wSF7vmwd0F6BCgEpT44bSpxHuMbfcmEKJPWGI2VhHRhQwtC74JB6VWk9XYEoP1pZCTLEPHol6r/zRpHJufWgKizLuDr/sh8PZo=</div>
